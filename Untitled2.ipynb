# %% [markdown]
# <a href="https://colab.research.google.com/github/deep1315/DataHour/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=23
b='HELLO'
c=[1,2,3,4]
d=(1,2,3,4)

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# list

# %%
type(d)
# Out:
# tuple
